# %%
import pandas as pd

# Load dataset
df = pd.read_parquet("../data/train.parquet")

# First look
print(df.head())
# Out:
#                                              context  \
# 0  A new social media platform has rapidly gained...
# 1  A large financial institution has recently imp...
# 2  A large multinational corporation has recently...
# 3  A regional bank has recently implemented a new...
# 4  A mid-sized tech company has recently implemen...
#
#                                                query  \
# 0  What is the risk level associated with the con...
# 1  What is the risk level of continuing operation...
# 2  What is the risk level of continuing operation...
# 3  What is the risk level of the bank facing a po...
# 4  What is the risk level of the new remote work ...
#
#                                              answers  risk_score
# 0  [Low risk, Moderate risk, High risk, Very high...          85
# 1  [Low risk, Moderate risk, High risk, Very high...          85
# 2  [Low risk, Moderate risk, High risk, Very high...          85
# 3  [Low risk, Moderate risk, High risk, Very high...          75
# 4  [Low risk, Moderate risk, High risk, Very high...          65

# %%
print("Rows, Columns:", df.shape)
# Out:
# Rows, Columns: (513, 4)

# %%
print(df.columns)
# Out:
# Index(['context', 'query', 'answers', 'risk_score'], dtype='object')

# %%
print(df.isnull().sum())
# Out:
# context       0
# query         0
# answers       0
# risk_score    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

df["risk_score"].hist(bins=20)
plt.xlabel("Risk Score")
plt.ylabel("Count")
plt.title("Risk Score Distribution")
plt.show()
